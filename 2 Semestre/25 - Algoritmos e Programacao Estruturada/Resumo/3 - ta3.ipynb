# %% [markdown]
# # ***RESUMO***
# * Funções;
# * Funções com parâmetros;
# * Escopo e Passagem de Parâmetros;
# * Recursividade;

# %% [markdown]
# *********************************************
# ********************************************

# %% [markdown]
# # Função em python

# %%
lista = [123, 456, 789]
dados = []

def outra():
    for i in lista:
        busca = (navegador(i))
        dados.append(busca)
    
    return dados

def navegador(i):
    if i == 123:
        status = "ROTA"
        data = "10/10/2023"
    elif i == 456:
        status = "ENTREGUE"
        data = "20/20/2023"
    else:
        status = "sem dados"
        data = "sem dados"
    return i, status, data

outra()
print(dados)
# Out:
# [(123, 'ROTA', '10/10/2023'), (456, 'ENTREGUE', '20/20/2023'), (789, 'sem dados', 'sem dados')]

# %% [markdown]
# # função em C

# %%
#include <stdio.h>

int lista[] = {123, 456, 789};

void navegador(int i) {
    const char* status;
    const char* data;

    if (i == 123) {
        status = "ROTA";
        data = "10/10/2023";
    } else if (i == 456) {
        status = "ENTREGUE";
        data = "20/20/2023";
    } else {
        status = "sem dados";
        data = "sem dados";
    }

    printf("ID: %d, Status: %s, Data: %s\n", i, status, data);
}

int main() {
    for (int i = 0; i < sizeof(lista) / sizeof(lista[0]); i++) {
        navegador(lista[i]);
    }
    return 0;
}

# %% [markdown]
# # ***FUNÇÕES***
# Técnica dividir para conquistar
#
#
# Trecho de código escrito para solucionar um
# subproblema;
#
# - Dividir a complexidade de um problema maior;
# - Evitar repe9ção de código;
# - Modularização;

# %% [markdown]
# # ***Funções com Ponteiros***
#
# # Ponteiro
#
# resumo: Referenciar o programa através de alocação de memória, indicando o endereço de memória da variavel
#
# # Ponteiro é Tipo especial de variável, que armazena um endereço de memória;
# O acesso à memória é feito usando dois operadores:
# * Asterisco (*):
#     * usado para criação do ponteiro;
# * “&” :
#     * Acessar o endereço da memória; exemplo o scanf
#
#
# Estrutura de como declaramos um Ponteiro
#
# < tipo> *<nome_do_ponteiro>;
#
# Exemplo: int *idade;
#
# A criação de um ponteiro só faz sentido se for
# associada a algum endereço de memória.

# %% [markdown]
#
#     int variavel = 10;
#     int *ponteiro_para_variavel = &variavel;
#
#     ##include <stdio.h>
#         int main(){
#             int x;
#             x = 10;
#             printf("print variavel, tipo primitivo (%%d):%i\n", x);
#             printf("print variavel com o &, e tipo primitivo (%%p): %p\n", &x);
#             printf("===================================\n");
#
#             int *ponteiro_de_x;
#             ponteiro_de_x = &x;
#             printf("print ponteiro, tipo primitivo (%%d), e com (*): %i\n", *ponteiro_de_x);
#             printf("print ponteiro, tipo primitivo (%%p), e sem (*) %p\n", ponteiro_de_x);
#             printf("===================================\n");
#             return 0;

# %% [markdown]
# # Resultado do código acima
#
# Resumindo a chamada do ponteiro:
#
# - Qunado utilizamos "*Ponteiro" (COM ASTERÍSCO)
#     - irá retornar o VALOR CONTEÚDO da variavel apontada
#
# * Qunado NÂO utilizamos Ponteiro (SEM ASTERISCO)
#     - irá retornar o ENDEREÇO DE MEMÓRIA da variavel apontada
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # COmo utilizar VETOR em funções, e a maneira correta de declarar
#
# * Forma errada de declarar um vetor em funções
#
#         tipo[10] nome() ------------>  # ERRADO
#
# * O correto para este caso é u9lizar ponteiros. --------> # MANEIRA CORRETA
#
#         tipo *nomer(){
#            int vetor[10];
#            return vetor;
#         }
#
#
# EXEMPLO:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # ***Função malloc()***
# * Alocar memória dinamicamente;
# * Exemplo:
#
#         int* memoria = malloc (100);
# * Retorna dois valores: NULL(deu errrado) ou um PONTEIRO GENÉRICO;

# %%
EXEMPLO:

#include <stdio.h>
#include <stdlib.h> // Para a função rand e malloc

int* gerarRandomico() {
    int* r = (int*)malloc(10 * sizeof(int)); // Aloca memória dinamicamente
    int a;
    
    if (r != NULL) { // Verifica se a alocação de memória foi bem-sucedida
        for (a = 0; a < 10; ++a) {
            r[a] = rand();
            printf("r[%d] %d\n", a, r[a]);
        }
    } else {
        // Lida com a falha na alocação de memória
        printf("Erro na alocação de memória.\n");
    }
    
    return r;
}

int main() {
    int* randomNumbers = gerarRandomico();
    
    // Use os números aleatórios conforme necessário
    
    free(randomNumbers); // Libera a memória alocada
    
    return 0;
}
# Out:
#   Cell In[1], line 1
#     EXEMPLO:
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# .
# ![image.png](attachment:image.png)

# %% [markdown]
# ***********************************
# *************************************

# %% [markdown]
# # ***Escopo e Passagem de Parâmetros***
#
# # **_Escopo_:**
#
#
# # Variável Local:
# * são “enxergadas” somente dentro
# do corpo da função onde foram definidas;
#
# # Variável Global:
# * criá-la fora da função, assim ela
# será visível por todas as funções do programa.
# Geralmente adota-se declará-las após as
# bibliotecas.
#
# EXEMPLO:

# %%
#include,stdio.h>

int x=10;
int testar(){
    return 2*x;
}
int main(){
    printf("\n Valor de x global = %d"; x);
    printf("\n Valor de x global ALTERADO NA FUNÇÂO TESTAR() = %d"; testar());
    return 0;
}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Parâmetros
# Ideal  para ser acessada por outra função, o valor da variavel ("pai") não será alterada , só será alterada dentro da função que chamar ela de acordo com seus comando, mas ao finalisar a função atuala a variavel principal volta a ter seu valor original como antes
#
# Passagem de Valor:
# * a função cria variáveis locais
# automaticamente para armazenar esses valores e
# após a execução da função essas variáveis são
# liberadas.
#
# ![Alt text](image-7.png)

# %% [markdown]
# # Passagem por referência
# Se alterada em qualquer parte do codigo, o valor da varialvel original (pai) será alterada, e passa ater um novo valor
#
# * Ponteiro e endereço de memória;
# * Não será criada uma cópia dos argumentos
# passados;
# * Será passado o endereço da variável e função
# trabalhará diretamente com os valores ali
# armazenados;

# %% [markdown]
# **************************************************
# ******************************************

# %% [markdown]
# # ***FUNÇÃO RECURSIVA***
# Um algoritmo recursivo resolve um problema
# dividindo-o em subproblemas mais simples, cujo a
# solução é a aplicação dele mesmo.
# * Ponto de Parada;
#     -  (precisa se não o codigo pode rodar infinito)
# * Variáveis na memória de trabalha;
#     - (pode acabar pesando a memoria, pode acontecer estouro de pilha)
# * As variáveis são independentes;
#
# ![Alt text](image-8.png)
# ![Alt text](image-9.png)
