# %% [markdown]
# # ***Resumo***
#
# * Definição de tabela-verdade;
# * Construção de tabela-verdade;
# * Validação entre as suas proposições;
#
# - Competência da Unidade: desenvolver e praticar o
# raciocínio lógico utilizando a tabela verdade para que,
# ao final da unidade, você conheça e saiba aplicar os
# seus conceitos e fundamentos a partir de cases e
# aplicações computacionais.
# - Resumo: Aplicação de tabelas verdade na solução
# computacional.

# %% [markdown]
# *********************
# ******************

# %% [markdown]
# # ***Tabela Verdade***
#
# # ~
# 		(negacão)
# 			O til corresponde à operação lógica NEGAÇÃO. Alguns autores também utilizam o símbolo  <--- para designar negação.
#
# # ∧
# 		(conjunção - AND, &)
# 			A cunha corresponde à operação lógica CONJUNÇÃO. Em programação, a conjunção é representada pela palavra AND, ou pelo símbolo   &, que corresponde ao conectivo  e
#
# # ∨
# 		(disjunção - OR, OU)
# 			A letra v corresponde à operação lógica DISJUNÇÃO. Equivale à palavra ou em seu sentido inclusivo. Em programação, a conjunção é também representada pela palavra OR.
#
# # →
# 		(condicional - SE, ENTÂO)
# 			A seta corresponde à operação CONDICIONAL. Em português, corresponde à relação “se..., então...”.
#
# # ↔
# 		(condicional - SE , SOMENTE SE)
# 			A dupla seta corresponde à operação BICONDICIONAL. Em português, corresponde à relação “se, e somente se, …”.
#
#
#
# Uma tabela verdade é uma tabela que lista todas as possíveis combinações de valores de verdade para um conjunto de proposições (variáveis) em uma expressão lógica. Ela mostra o valor de verdade resultante da expressão lógica para cada combinação de valores das variáveis. Aqui está um exemplo simples de uma tabela verdade para a operação lógica de conjunção (E lógico) entre duas proposições, P e Q:
#
# | P | Q | P ∧ Q |
# |---|---|-------|
# | V | V |   V   |
# | V | F |   F   |
# | F | V |   F   |
# | F | F |   F   |
#
# Nesta tabela verdade:
#
# - "P" e "Q" são as variáveis proposicionais.
# - "V" representa "verdadeiro" e "F" representa "falso".
# - "P ∧ Q" representa a conjunção lógica entre P e Q.
#
# A tabela verdade mostra todas as quatro combinações possíveis de valores verdadeiros (V) e falsos (F) para P e Q, bem como o valor resultante da conjunção P ∧ Q para cada combinação.
#
# As tabelas verdade são úteis na lógica para analisar e avaliar expressões lógicas, determinar a validade de argumentos e realizar simplificações em expressões lógicas complexas. Elas também são usadas em circuitos lógicos, programação e em muitas outras aplicações da matemática e da ciência da computação.

# %% [markdown]
# # Matrizes de Conectivos - AND
# Como você pode ver, tanto o hardware como o software
# computacional dependem da Lógica Formal.
# Sabemos que os fundamentos da lógica computacional
# estão baseados nas proposições e nos conectivos (ou
# operadores) lógicos, mas como podemos organizar os
# resultados das operações lógicas para facilitar nosso
# trabalho?
#
# Podemos seguir a sugestão de Silva, Finger e Melo
# (2017) e construir matrizes de conectivos, conforme
# mostra o Quadro 4.1. No canto superior esquerdo, temos
# a operação lógica a ser feita, no caso AND (E).
# Nas linhas abaixo da operação, temos a proposição “P” e
# os possíveis valores que ela pode assumir, ou seja,
# verdadeira / falsa.
# Fonte: Shutterstock
#
# Nas colunas ao lado da operação, temos os valores da
# proposição “Q”, ou seja, também verdadeira / falsa.
# No centro da matriz estão os possíveis resultados lógicos
# para a operação AND.
# Veja que, quando P E Q são verdadeiras, o resultado é V.
# Para todos os demais casos, o resultado é falso (F).
#
# ![image.png](attachment:image.png)
#
# A representação dos resultados lógicos por meio de
# matrizes de conectores ajuda na organização, porém, limita
# uma operação por matriz. Como meio de organizar os
# resultados e facilitar a operação entre vários conectores em
# uma mesma estrutura, podemos utilizar a Tabela Verdade.
# Fonte: Shutterstock
# Quadro 4.1.

# %% [markdown]
# # Construção da Tabela Verdade
#
# Esquema geral de uma tabela verdade:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Segundo Jacob Daghlian (2006), para se construir a
# tabela-verdade de uma proposição composta dada,
# procede-se da seguinte maneira:
#
#         a) Determina-se o número de linhas da tabela-verdade
#         que se quer construir; 2n
#         b) Observa-se a precedência entres os conectivos, isto
#         é, determina-se a forma das proposições que ocorrem
#         no problema;
#         c)Aplicam-se as definições das operações lógicas que o
#         problema exigir.

# %% [markdown]
# *****************
# *************************

# %% [markdown]
# Exemplo comum de uma tabela verdade:
#
#
# .
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***************
# *****************

# %% [markdown]
# # ***Resultados na Tabela Verdade***
#
# # Condicional (se....então)
# * As proposições podem ser combinadas na forma
# “se proposição 1, então proposição 2”.
# * O conectivo lógico dessa combinação é o
# condicional, representado por ->, e significa que se
# a proposição 1 é verdadeira, implicará na verdade
# da proposição 2 (GERSTING, 2017).
# * Em outras palavras, podemos dizer que dada uma
# sequência de proposições, a partir da operação
# condicional é possível chegar a uma conclusão (um
# resultado), que é uma nova proposição.
# * A primeira parte, antes do conector, é chamada de
# antecedente, e a segunda de consequente.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# exemplo:
#
# Você foi encarregado da missão de direcionar a equipe de
# marketing em uma campanha para o dia internacional da
# mulher. Dadas as proposições:
#
#         A: o cliente é do sexo feminino.
#         B: o cliente fez um compra com valor superior a R$ 50,00.
#         C: ganhar cupom com 10% de desconto.
#
#         V^V=V, então a proposição C é V.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # ***Aplicações Tabela Verdade***
