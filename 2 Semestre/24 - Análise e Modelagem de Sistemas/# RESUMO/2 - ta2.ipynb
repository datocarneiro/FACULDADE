# %% [markdown]
# # ***Recapitulando***
# * Processo de negócio;
# * BPMN;
# * Gerenciamento de processos de negócio;
# * Maturidade do processo;
#
#         •Resumo: Conhecer e aplicar as técnicas e ferramentas de
#         modelagem e gerenciamento de processos de negócios
#         •Palavras-chave: BPMN; processo de negócios; CMMI; maturidade
#         do processo;
#         •Título da Teleaula: Processos de negócio para análise de sistemas
#         •Teleaula nº: 02

# %% [markdown]
# **********************
# ****************

# %% [markdown]
# # ***Processo  de negócio***
# Nada mais é que uma sequencia lógica estrutura de tarefas que é uma entrada um processo  e uma saida
#
# complexidade:
#
#          simples e complexos
#
# # Fundamentos:
#
#         ENTRADA -> OPERAÇÕES OU PROCESSAMENTOS -> SAÍDAS OU RESULTADOS
#
#         podem ser retroalimentadas ou não
#
#
# è importante ter uma visão geral de todo o precesso de negócio
#
# assim nós como analista conseguimos estudar onde o sistema vai estar inserido, quais funcionalidades do sistema vão estar envolvidos para cada departamento por exemplo
#
# # Os processos podem ser dividido em categorias
#         Macroprocesso
#         Processo
#         Sub Processo
#
#         processos maiores subdividivos em processos menores
#
# Exemplo:
#
# ![image-2.png](attachment:image-2.png)
#
#
# * SÃO DIVIDIDOS TAMBEM EM:
#
#         • Processos primários;
#         • Processos de suporte;
#         • Processo de gerenciamento;
#
#         Primário: São relacionados com o négocio proncipal, com agregação de valor ao cliente
#         Suporte: que auxilian os primarios (rh, entrega, contabilidade )
#         Gerencioamento: que buscar  fazer o gerencioamento com melhoria
#
#
# e para se ter uma boa visão do processo de negócio usamos a modelagem de sistema
# existem duas linguagem
#
#         * BPMN - (voltada para os preocessos de negócio, de facil compreenssão)
#                 O BPMN atua com diagrama único BPD (Business Process Diagram) que permite desenhar os mais diversos tipos de modelagem de processo (Brocke e Rosemann, 2013).
#                 . Esta técnica provê os recursos para que vários tipos de modelagem possam ser feitos, através dos diagramas de fluxo de trabalho. Cada diagrama contém o que deve ser feito e seu registro deve ser claro o suficiente para o entendimento fácil dos membros.
#
#         * UML -
#                 Dá suporte ao desenvolvimento de softwares e, é uma linguagem de representação gráfica especificada, é independente da metodologia de modelagem de processos adotada, sendo apenas um conjunto de convenções de modelagem (Valle e Oliveira, 2013).
#                 2. Técnica voltada a descrever os requisitos de sistemas de informação, representando um sistema de modo padronizado. Sua aplicação contempla a especificação, documentação,estruturação e visualização do sistema como um todo. É composta por diagramas agrupados nas categorias comportamental, estrutural e de interação.
#
#         * IDEF (Integrated DEFinition Language)
#                 O IDEF permite a modelagem de requisitos para sistemas, as técnicas IDEF0 e IDEF3 são utilizadas para modelagem de processos de negócios.
#                 1. Faz parte de uma família de linguagens que cobrem necessidades desde simulação, análise e desenho orientado a objeto, até aquisição de conhecimento, contemplando várias“gerações”, cada qual desenhada para uma função de modelagem. As entradas, saídas, mecanismos, controles e relação dos níveis de detalhe dos processos superior e inferiorsão destacados nesta técnica.
#
#         * EPC (Event-driven Process Chain)
#                 O EPC visa a modelagem com base no controle de fluxo de atividades e suas dependências. Tem foco essencialmente para descrição de processos.
#                 4. Conjuntos complexos de processos costumam demandar este modelo, embora sua característica esteja pautada nas notações simples e fáceis de serem entendidas que descrevem os processos e “workflows”. Seu desenvolvimento foi feito dentro do “framework” ARIS

# %% [markdown]
# # ***BPMN - Business Process Modeling Notation***
#
#     (voltada para os preocessos de negócio, de facil compreenssão)
#
# Nada mais é como se fosse um tipo de fluxograma, com a sua notação especifica, entendendo como uma empresa funciona no geral.
#
# é uma modelagem que fazemos envolvendo toda a empresa
#
# quais departamentos o sistema que vamos desenvolver, vai ter integração quias as funcionalidades
#
# Elementos básicos?
#
#     Atividade
#     Evento
#     Geteway
#     Conector
#     Picinas
#     Raias
#
#         Atividade - Como dse fosse uma funcionalidade, tarefa
#         Evento - ocorrencia de algo  no processo como inicio e fim por exemplo
#         Geteway - Decisão (tipo IF)
#         Conector - è o que liga os elementos dadndo o fluxo
#
#
# ![image-2.png](attachment:image-2.png)
#
# Exemplo:
#
# ![image.png](attachment:image.png)
#
# subprocessos:
#
# ![image-3.png](attachment:image-3.png)
#
# Eventos :
#
#  ![image-4.png](attachment:image-4.png)
#
# Geteway:
#
# ![image-5.png](attachment:image-5.png)
#
# Conectores:
#
# ![image-6.png](attachment:image-6.png)
#
# Picinas e raias:
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # ***BPMS***
#
# Nada mais é que ferramentas que nos ajudam automatizar nosso processos de negócio

# %% [markdown]
# # ***Gerenciamento de processos de negócio e Maturidade do Processo***
#  **"BPM – do inglês Business Process Management"**
#
#
# # Visão verticalizada.
#
# os processos organizacionais são vistos de
# uma forma diferente, pois a visão é ampliada, há uma percepção de toda a
# cadeia envolvida para entregar um produto ou serviço e não se trata de uma
# visão verticalizada
#
# A visão verticalizada permite que a organização seja percebida apenas de
# cima para baixo, e isto quer dizer que a relação entre as áreas não é percebida, como se
# as atividades fossem isoladas
#
# Para a Association Of Business Process Management Professionals
# International – ABPMP (2013), o BPM é necessário para olhar para o
# processo de um nível mais elevado do que o de execução do trabalho, pois
# apenas vendo o todo do processo será possível entender a relação entre as
# áreas e subdividi-lo por subprocessos que serão executados por diversas
# atividades (fluxos de trabalho) dentro das áreas funcionais. A Figura 2.23
# mostra a diferença de entendimento da visão física das funções, representada
# pelas atividades, e a visão lógica, representada pelos processos.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# * Os controles estratégicos
#
#         trazem uma visão mais genérica, de longo prazo e abordam a
#         organização como um todo.
#
# * Os controles táticos
#
#         são mais detalhados, de
#         médio prazo e abordam a organização em uma perspectiva departamental, departamentos especificos
#
# * Os Controles operacionais
#
#         são analíticos, de curto prazo e
#         voltados às tarefas e atividades

# %% [markdown]
# # ***CMMI***
#
# O SEI (Software Engineering Institute) é o responsável pela criação do
# CMMI, que é a descrição dos elementos-chave de um processo de software
# eficaz. O CMM é baseado em cinco níveis de maturidade, com o intuito das
# empresas de software evoluírem seu processo
#
# CMMI é composta por até (25) vinte e cinco áreas de processos,
# bem como seus objetivos e práticas. E suas vinte e cinco áreas são divididas
# em (4) quatro grupos
#
# * Gerenciamento de processos.
# * Gerenciamento de projetos.
# * Engenharia.
# * Apoio.

# %% [markdown]
# # **Maturiade do CMMI.***
#
# Como podemos perceber, a Figura demonstra os níveis de maturiade do CMMI.
#
# * No primeiro nível
#
#         é dito que o sucesso depende de heróis, pois não existem padrões;
#
# * no segundo nível
#
#         há planejamento, medição e controle dos processos;
#
# * no nível três
#
#         os processos são definidos e compreendidos pela empresa com procedimentos padrão estabelecidos e com previsibilidade de aplicação em outros projetos;
#
# * no quatro,
#
#         com o controle quantitativo há possibilidade de prever o desempenho;
#
# * e no último nível,
#
#         o foco está na melhoria continuada dos processos.
