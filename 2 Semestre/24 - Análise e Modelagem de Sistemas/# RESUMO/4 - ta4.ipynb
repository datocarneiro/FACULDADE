# %% [markdown]
# # ***Recapitulando***
#
# * Fundamentos da orientação a objetos;
# * Diagrama de classes;
# * Processo unificado;
# * Diagrama de sequência;
# * Diagrama de atividades;
# * Diagrama de máquina de estados.
#
# - Competência da Unidade: modelar um software usando o
# processo unificado iterativo e incremental utilizando UML
# - Resumo: Compreender o paradigma orientado a objetos e
# conhecer diagramas da UML;
# - Palavras-chave: Processo unificado, UML, diagrama de classes,
# diagrama de atividades.

# %% [markdown]
# *****************
# ******************

# %% [markdown]
# # ***Paradigma Orientado a Objetos (POO)***
# * È um Padrão de desenvolvimento;
#     * modela usando modelos do mundo real
# * Como modelar os problemas do mundo real;
# * Smaltalk 80;
#     * foi criado na década de 60  em (1966), mas to tomou forma mesmo nos anos 80 com a smalltalk 80
# * C++;
#     * C++ foi quem deu origem (++, significa if class )

# %% [markdown]
# # * Conceitos básicos da POO*
#
# *  Abstração;
#     - idéia central
# *  Classe;
#     - representa as caracteristicas
# *  Atributos e métodos;
#     - ações
# *  Objeto;
#     - materialização de forma única da classe
# *  Herança;
#     - classes que derivam de outras classes (tipo Pai, filho)
# *  Encapsulamento;
#     - proteção dos atributos (permissão)
# *  Polimorfismo;
#     - objeto do  mesmo tipo com comportamentos diferentes

# %% [markdown]
# # **Associando a utilização da POO**
#
# # 1 -  exemplo de uma receita de bolo
#
#         o que ela possui?
# * # **receita (classe)**
# * # **ingredientes  (atributos/parametros)**
# * # **modo de fazer (metodos)**
#
#         porem existem vários tipos de bolo, de chocolate, laranja  etc... e cada bolo vai ingredientes(valores de attributos/parametros diferentes) diferentes
#
#         e no final se tem o objeto que é o resultado de uma receita de bolo (classe)

# %% [markdown]
# # 1 -  Construção de cadeira
#
# ![image.png](attachment:image.png)
